# %%
import pandas
from geopy.geocoders import Nominatim

# %%
locator = Nominatim(user_agent="myGeocoder")
location = locator.geocode("Champ de Mars, Paris, France")
print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))
# Out:
# Latitude = 48.85614465, Longitude = 2.297820393322227

# %%
pandas.read_excel("sample.xlsx")
# Out:
#      ROWNUM        patient_name patient_sex  patient_mobile  patient_age  \
# 0         1        SURESH KUMAR        Male      9815450409           39
# 1         2       SANTOSH KUMAR        Male      9465251998           46
# 2         3               ANOOP        Male      9399630804           26
# 3         4              MUNISH        Male      9872216010           42
# 4         5     TARLOCHAN SINGH        Male      9988993885           57
# ..      ...                 ...         ...             ...          ...
# 994     995    RUTH SONIA TOPPO      Female      9356623300           27
# 995     996           RITA RANI      Female      9877481748           48
# 996     997          MEWA SINGH        Male      9878906357           67
# 997     998  AMARJIT KAUR WALIA      Female      9815100614           72
# 998     999               BABLI      Female      7973953668           42
#
#     patient_district_name                patient_address patient_occupation  \
# 0                BATHINDA                       bathinda              Other
# 1              HOSHIARPUR                    CITY DASUYA              Other
# 2               PATHANKOT                   RO PATHANKOT              Other
# 3               JALANDHAR                    BHARGO CAMP              Other
# 4                 PATIALA        VILL. SHEKHPURA ENCLAVE              Other
# ..                    ...                            ...                ...
# 994              LUDHIANA               CMC AND HOSPITAL              Other
# 995           S.A.S Nagar          3348 SECTOR 70 MOHALI              Other
# 996               SANGRUR                  VILLAGE BANGA              Other
# 997             JALANDHAR  HNO 614-R THE MALL MODEL TOWN              Other
# 998               FAZILKA            DELHI PUBLIC SCHOOL              Other
#
#     patient_designation id_type_name  ... time_of_isolation_Id  \
# 0                   NaN       SRF ID  ...                    0
# 1                   NaN       SRF ID  ...                    0
# 2                   NaN       SRF ID  ...                    0
# 3                   NaN       SRF ID  ...                    0
# 4                   NaN       SRF ID  ...                    0
# ..                  ...          ...  ...                  ...
# 994                 NaN       SRF ID  ...                    0
# 995                 NaN       SRF ID  ...                    0
# 996                 NaN       SRF ID  ...                    0
# 997                 NaN       SRF ID  ...                    0
# 998                 NaN       SRF ID  ...                    0
#
#     time_of_outcome_name  time_of_outcome_Id  contact_patient_mobile  \
# 0                    NaN                   0                     NaN
# 1                    NaN                   0                     NaN
# 2                    NaN                   0                     NaN
# 3                    NaN                   0                     NaN
# 4                    NaN                   0                     NaN
# ..                   ...                 ...                     ...
# 994                  NaN                   0                     NaN
# 995                  NaN                   0                     NaN
# 996                  NaN                   0                     NaN
# 997                  NaN                   0                     NaN
# 998                  NaN                   0                     NaN
#
#     traceable_id hi_Completion_status hi_Completion_date  \
# 0              1                    N                NaN
# 1              1                    N                NaN
# 2              1                    N                NaN
# 3              1                    N                NaN
# 4              1                    N                NaN
# ..           ...                  ...                ...
# 994            1                    N                NaN
# 995            1                    N                NaN
# 996            1                    N                NaN
# 997            1                    N                NaN
# 998            1                    N                NaN
#
#      patient_active_status      icmr_Id       patient_Id
# 0                        Y  289276071.0          R008725
# 1                        Y  284943521.0     nCoV-1633251
# 2                        Y  284702837.0  2019-nCoV163597
# 3                        Y  287965589.0           993203
# 4                        Y  284787179.0           592380
# ..                     ...          ...              ...
# 994                      Y  143157249.0           G92601
# 995                      Y  289423694.0  PBTI-nCov-17419
# 996                      Y  289024483.0      ncov1611171
# 997                      Y  288383298.0           683686
# 998                      Y  281628734.0           144701
#
# [999 rows x 76 columns]
